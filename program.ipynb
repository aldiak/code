# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

t = 1
x = np.array([-1.3, 1.3])
a = 0.1
b = 0.7
def func(x):
    return np.exp(x[0] + 3 * x[1] - 0.1) +np.exp(x[0] - 3 * x[1] - 0.1) + np.exp(- x[0] - 0.1)

def dfunc(x):
    dfx1 = np.exp(x[0] + 3 * x[1] - 0.1) +np.exp(x[0] - 3 * x[1] - 0.1) - np.exp(- x[0] - 0.1)
    dfx2 = 3 * np.exp(x[0] + 3 * x[1] - 0.1) - 3 * np.exp(x[0] - 3 * x[1] -0.1)
    return  np.array([dfx1, dfx2]) 

def dfunc2(x):
    dfx11 = np.exp(x[0] + 3 * x[1] - 0.1) +np.exp(x[0] - 3 * x[1] - 0.1) - np.exp(- x[0] - 0.1)
    dfx12 = 3 * np.exp(x[0] + 3 * x[1] - 0.1) - 3 * np.exp(x[0] - 3 * x[1] -0.1)
    dfx21 = 3 * np.exp(x[0] + 3 * x[1] - 0.1) - 3 * np.exp(x[0] - 3 * x[1] -0.1)
    dfx22 = 3 * np.exp(x[0] + 3 * x[1] - 0.1) - 3 * np.exp(x[0] - 3 * x[1] -0.1)
    return  np.array([[dfx11, dfx12], [dfx21, dfx22]]) 

def backtracking(x,t, a, b, d):
   
    d = - dfunc(x)
    while func(x + t*d) > func(x) + a*t* dfunc(x).dot(d):
        t += b * t
        print(t)
        return t

# %%
import numpy as np
import numpy.linalg as la

import scipy.optimize as sopt

import matplotlib.pyplot as pt
from mpl_toolkits.mplot3d import axes3d

def func(x):
    return np.exp(x[0] + 3 * x[1] - 0.1) + np.exp(x[0] - 3 * x[1] - 0.1) + np.exp(- x[0] - 0.1)

def dfunc(x):
    df1 = np.exp(x[0] + 3 * x[1] - 0.1) + np.exp(x[0] - 3 * x[1] - 0.1) - np.exp(- x[0] - 0.1)
    df2 = 3 * np.exp(x[0] + 3 * x[1] - 0.1) - 3 * np.exp(x[0] - 3 * x[1] -0.1)
    return  np.array([df1, df2]) 

fig = pt.figure()
ax = fig.gca(projection="3d")

xmesh, ymesh = np.mgrid[-2:2:50j,-2:2:50j]
fmesh = func(np.array([xmesh, ymesh]))
ax.plot_surface(xmesh, ymesh, fmesh)

# %%
pt.axis("equal")
pt.contour(xmesh, ymesh, fmesh)

# %%
guesses = np.array([2, 2./5])

# %%
x = guesses[-1]
s = -dfunc(x)

def f1d(alpha):
    return f(x + alpha*s)

alpha_opt = sopt.golden(f1d)
next_guess = x + alpha_opt * s
guesses.append(next_guess)

print(next_guess)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-143d3b4f343b> in <module>
#       1 x = guesses[-1]
# ----> 2 s = -dfunc(x)
#       3
#       4 def f1d(alpha):
#       5     return f(x + alpha*s)
#
# <ipython-input-7-421fd5e2714c> in dfunc(x)
#      11
#      12 def dfunc(x):
# ---> 13     df1 = np.exp(x[0] + 3 * x[1] - 0.1) + np.exp(x[0] - 3 * x[1] - 0.1) - np.exp(- x[0] - 0.1)
#      14     df2 = 3 * np.exp(x[0] + 3 * x[1] - 0.1) - 3 * np.exp(x[0] - 3 * x[1] -0.1)
#      15     return  np.array([df1, df2])
#
# IndexError: invalid index to scalar variable.
